# %% [markdown]
# # AI-generated GNSS Analysis Tool, Instructions.
#
# This notebook contains "*AI Skills* " (aka: "*custom instructions* "), so you can generate analysis code using simple prompts.
#
# To generate your own analysis code; to read and parse data from a GnssLogger file:
# *   Click on the "Toggle Gemini" icon below.
# *   Click the settings icon in the Gemini side-panel.
# *   Select "✓ Reading and parsing GNSS log file".
# *   Write a short prompt, like: "Read a GNSS log file, parse the data into dataframes ready for analysis"
#
# Follow similar steps, selecting the appropriate custom instruction, and adding a prompt to match. When you select a new custom instruction, select 'Keep Existing Chat' when prompted.
#
# **Simple examples with minimal prompts** <br>
# (add to these prompts to make code customized for your applications).
# 1. Reading a log file<br>
#   Skill (aka *Custom Instruction*):&ensp;✓ Reading and parsing GNSS log file<br>
#   Prompt: "Read a GNSS log file, parse the data into dataframes ready for analysis"
# 2. Plotting the data<br>
#   Skill:&ensp;✓ Plotting GNSS Data<br>
#   Prompt: "Plot FIX positions on a map. By signal type: Plot histograms of CN0; Plot number of signals vs time. Make a skyplot of satellite positions. Create an interactive time plot where the user can select the fields to plot, use 'AgcDb', 'Cn0DbHz' as the default"
# 3. Computing pseudoranges<br>
#   Skill:&ensp;✓ Compute and plot pseudoranges<br>
#   Prompt: "Compute and plot pseudoranges vs time, segmented by signal type"
# 4. Computing WLS position<br>
#   Skill:&ensp;✓ WLS Position Computation with ISRBs<br>
#   Prompt: "Compute WLS positions, plot as lat,lon on a map"
